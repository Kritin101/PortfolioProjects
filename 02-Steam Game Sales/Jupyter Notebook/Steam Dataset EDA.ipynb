# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 20)

# %%
Games = pd.read_excel(r'C:\Users\Kritin\Desktop\Imarticus\Capstone Project 1\Steam Game Dataset\games.xlsx')

# %%
Games.shape
# Out:
# (85123, 39)

# %%
Games.head()
# Out:
#      AppID                   Name  Release date Estimated owners Peak CCU  \
# 0    20200       Galactic Bowling  Oct 21, 2008        0 - 20000        0
# 1   655370           Train Bandit  Oct 12, 2017        0 - 20000        0
# 2  1732930           Jolt Project  Nov 17, 2021        0 - 20000        0
# 3  1355720             Henosisâ„¢  Jul 23, 2020        0 - 20000        0
# 4  1139950  Two Weeks in Painland   Feb 3, 2020        0 - 20000        0
#
#   Required age  Price DLC count  \
# 0            0  19.99         0
# 1            0   0.99         0
# 2            0   4.99         0
# 3            0   5.99         0
# 4            0      0         0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSISâ„¢ is a mysterious 2D Platform Puzzler...
# ...

# %%
Games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85123 entries, 0 to 85122
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AppID                       85107 non-null  object
#  1   Name                        85103 non-null  object
#  2   Release date                85109 non-null  object
#  3   Estimated owners            85108 non-null  object
#  4   Peak CCU                    85109 non-null  object
#  5   Required age                85108 non-null  object
#  6   Price                       85108 non-null  object
#  7   DLC count                   85109 non-null  object
#  8   About the game              81518 non-null  object
#  9   Supported languages         85103 non-null  object
#  10  Full audio languages        85103 non-null  object
#  11  Reviews                     9749 non-null   object
#  12  Header image                85102 non-null  object
# ...

# %%
Games.describe()
# Out:
#         AppID                                           Name  Release date  \
# count   85107                                          85103         85109
# unique  85107                                          84370          4473
# top     20200  Shadow of the Tomb Raider: Definitive Edition  Jul 14, 2023
# freq        1                                             20           102
#
#        Estimated owners  Peak CCU  Required age  Price  DLC count  \
# count             85108     85109         85108  85108      85109
# unique               17      1449            21    587         99
# top           0 - 20000         0             0      0          0
# freq              55285     62436         83463  16461      73263
#
#                                            About the game Supported languages  \
# count                                               81518               85103
# unique                                              81080               11309
# ...

# %%
Games.isnull().sum()
# Out:
# AppID                  16
# Name                   20
# Release date           14
# Estimated owners       15
# Peak CCU               14
#                     ...
# Categories           4619
# Genres               3576
# Tags                21115
# Screenshots          2027
# Movies               6472
# Length: 39, dtype: int64

# %%
#Getting the column names in alphabetical order

Games.columns.sort_values().values
# Out:
# array(['About the game', 'Achievements', 'AppID',
#        'Average playtime forever', 'Average playtime two weeks',
#        'Categories', 'DLC count', 'Developers', 'Estimated owners',
#        'Full audio languages', 'Genres', 'Header image', 'Linux', 'Mac',
#        'Median playtime forever', 'Median playtime two weeks',
#        'Metacritic score', 'Metacritic url', 'Movies', 'Name', 'Negative',
#        'Notes', 'Peak CCU', 'Positive', 'Price', 'Publishers',
#        'Recommendations', 'Release date', 'Required age', 'Reviews',
#        'Score rank', 'Screenshots', 'Support email', 'Support url',
#        'Supported languages', 'Tags', 'User score', 'Website', 'Windows'],
#       dtype=object)

# %%
# Dropping columns that we don't need

Games.drop(['About the game', 'Achievements', 'Average playtime forever', 
            'Average playtime two weeks', 'Developers','Full audio languages',
            'Header image', 'Median playtime forever', 'Median playtime two weeks',
            'Metacritic score','Metacritic url', 'Movies', 'Negative','Notes',
            'Positive', 'Publishers','Recommendations', 'Required age',
            'Reviews', 'Score rank', 'Screenshots', 'Support email', 'Support url', 
            'User score', 'Website', 'Tags', 'Peak CCU'], axis=1, inplace=True)

# %%
Games
# Out:
#          AppID                     Name  Release date Estimated owners  Price  \
# 0        20200         Galactic Bowling  Oct 21, 2008        0 - 20000  19.99
# 1       655370             Train Bandit  Oct 12, 2017        0 - 20000   0.99
# 2      1732930             Jolt Project  Nov 17, 2021        0 - 20000   4.99
# 3      1355720               Henosisâ„¢  Jul 23, 2020        0 - 20000   5.99
# 4      1139950    Two Weeks in Painland   Feb 3, 2020        0 - 20000      0
# ...        ...                      ...           ...              ...    ...
# 85118  2669080  Mannerheim's Saloon Car   Jan 2, 2024            0 - 0      0
# 85119  2736910                 Beer Run   Jan 3, 2024            0 - 0      0
# 85120  2743220     My Friend The Spider   Jan 4, 2024            0 - 0      0
# 85121  2293130        Path of Survivors   Jan 8, 2024            0 - 0   3.99
# 85122  2738840          The Night Heist   Jan 5, 2024            0 - 0   9.99
#
# ...

# %%
Games.isnull().sum()
# Out:
# AppID                    16
# Name                     20
# Release date             14
# Estimated owners         15
# Price                    15
# DLC count                14
# Supported languages      20
# Windows                  21
# Mac                      20
# Linux                    20
# Categories             4619
# Genres                 3576
# dtype: int64

# %% [markdown]
# #### Cleaning AppID

# %%
Games.loc[Games['AppID'].isna(),"Name"]
# Out:
# 75724        NaN
# 79461        NaN
# 79462        NaN
# 79463        NaN
# 79489        NaN
# 79490        NaN
# 79491        NaN
# 79492    ä»çŽ‹2
# 82889        NaN
# 82890        NaN
# 82891        NaN
# 83393        NaN
# 84544        NaN
# 84545        NaN
# 84546        NaN
# 84547    ä»çŽ‹2
# Name: Name, dtype: object

# %%
Games.loc[Games['AppID'].isna()]
# Out:
#       AppID     Name      Release date  Estimated owners  \
# 75724   NaN      NaN               NaN               NaN
# 79461   NaN      NaN               NaN               NaN
# 79462   NaN      NaN               NaN               NaN
# 79463   NaN      NaN               NaN               NaN
# 79489   NaN      NaN               NaN               NaN
# 79490   NaN      NaN               NaN               NaN
# 79491   NaN      NaN               NaN               NaN
# 79492   NaN  ä»çŽ‹2  è³½åšæœ‹å…‹2077  å¥³ç¥žç•°èžéŒ„5
# 82889   NaN      NaN               NaN               NaN
# 82890   NaN      NaN               NaN               NaN
# 82891   NaN      NaN               NaN               NaN
# 83393   NaN      NaN               NaN               NaN
# 84544   NaN      NaN               NaN               NaN
# 84545   NaN      NaN               NaN               NaN
# 84546   NaN      NaN               NaN               NaN
# ...

# %% [markdown]
# Looks like these are empty or intangible rows hence we wiil drop it

# %%
Games.drop(index=Games[Games['AppID'].isna()].index, inplace=True)

# %%
Games.loc[Games['AppID'].isna(),"Name"].count()
# Out:
# 0

# %%
Games.shape
# Out:
# (85107, 12)

# %%
Games.isnull().sum()
# Out:
# AppID                     0
# Name                      6
# Release date              0
# Estimated owners          1
# Price                     1
# DLC count                 0
# Supported languages       6
# Windows                   7
# Mac                       6
# Linux                     6
# Categories             4605
# Genres                 3562
# dtype: int64

# %% [markdown]
# #### Cleaning Name

# %%
Games.loc[Games['Name'].isna()]
# Out:
#          AppID Name  Release date Estimated owners Price DLC count  \
# 25222   396420  NaN   Nov 1, 2016            0 - 0     0         0
# 72038  1116910  NaN  Sep 25, 2019            0 - 0  6.99         0
# 77217  1365520  NaN  Aug 30, 2020            0 - 0     0         0
# 77489  1080790  NaN  Jul 12, 2019            0 - 0     0         0
# 77563  1256960  NaN  Mar 11, 2020        0 - 20000     0         0
# 77723  1172120  NaN  Jan 23, 2020            0 - 0     0         0
#
#                                      Supported languages Windows    Mac  \
# 25222                                                 []    True  False
# 72038                                                 []    True  False
# 77217  ['English', 'French', 'Italian', 'German', 'Sp...    True  False
# 77489                                        ['English']    True  False
# 77563                                        ['English']    True  False
# ...

# %% [markdown]
# There are just 6 records so we can drop it

# %%
Games.shape
# Out:
# (85107, 12)

# %%
Games.drop(index=Games[Games['Name'].isna()].index, inplace=True)

# %%
Games.shape
# Out:
# (85101, 12)

# %%
Games.isnull().sum()
# Out:
# AppID                     0
# Name                      0
# Release date              0
# Estimated owners          1
# Price                     1
# DLC count                 0
# Supported languages       6
# Windows                   7
# Mac                       6
# Linux                     6
# Categories             4602
# Genres                 3560
# dtype: int64

# %% [markdown]
# #### Cleaning Estimated owners

# %%
Games.loc[Games['Estimated owners'].isna()]
# Out:
#                                                    AppID  \
# 75725  ½™æ¬¡æ•°ã€‚ 3ã€é“œé’±çš„åŸºç¡€æ•°é‡ä¼šéšç€...
#
#                          Name            Release date Estimated owners Price  \
# 75725  ['Simplified Chinese']  ['Simplified Chinese']              NaN   NaN
#
#                     DLC count Supported languages Windows    Mac  Linux  \
# 75725  zhouzhou901514@163.com               False     NaN  False  False
#
#       Categories Genres
# 75725        NaN    NaN

# %% [markdown]
# Looks like it is a corupted record so we will drop it

# %%
Games.shape
# Out:
# (85101, 12)

# %%
Games.drop(index=Games[Games['Estimated owners'].isna()].index, inplace=True)

# %%
Games.shape
# Out:
# (85100, 12)

# %%
Games.isnull().sum()
# Out:
# AppID                     0
# Name                      0
# Release date              0
# Estimated owners          0
# Price                     0
# DLC count                 0
# Supported languages       6
# Windows                   6
# Mac                       6
# Linux                     6
# Categories             4601
# Genres                 3559
# dtype: int64

# %% [markdown]
# #### Cleaning Supported languages

# %%
Games.loc[Games['Supported languages'].isna()]
# Out:
#          AppID                                         Name  Release date  \
# 75723  2482450                                 åŽå‘åˆ¶äºº  Jul 11, 2023
# 79460  2520880                                 ä¹±ç«æˆ˜èˆž   Sep 7, 2023
# 79488  2642660  æœ«æ—¥æˆ˜å§¬-äºŒæ¬¡å…ƒ.ç­–ç•¥.å¡ç‰Œ.æ¸¸æˆ  Nov 16, 2023
# 82888  2445600                                 ç¥žæ˜Žä¹‹æ—…  Sep 21, 2023
# 83392  2532200                               Be The Richest  Aug 14, 2023
# 84543  2389120                                 æˆ˜å§¬å†›å›¢  Dec 18, 2023
#
#       Estimated owners Price DLC count Supported languages Windows  Mac Linux  \
# 75723            0 - 0     0         0                 NaN     NaN  NaN   NaN
# 79460            0 - 0     0         0                 NaN     NaN  NaN   NaN
# 79488            0 - 0     0         0                 NaN     NaN  NaN   NaN
# 82888            0 - 0     0         0                 NaN     NaN  NaN   NaN
# ...

# %% [markdown]
# These games were cancelled so we will drop it

# %%
Games.shape
# Out:
# (85100, 12)

# %%
Games.drop(index=Games[Games['Supported languages'].isna()].index, inplace=True)

# %%
Games.shape
# Out:
# (85094, 12)

# %%
Games.isnull().sum()
# Out:
# AppID                     0
# Name                      0
# Release date              0
# Estimated owners          0
# Price                     0
# DLC count                 0
# Supported languages       0
# Windows                   0
# Mac                       0
# Linux                     0
# Categories             4595
# Genres                 3553
# dtype: int64

# %% [markdown]
# #### Cleaning Categories & Genre

# %%
Games.loc[Games['Categories'].isna()]
# Out:
#          AppID                         Name         Release date  \
# 31     1727670           Home Office Tasker          Sep 8, 2021
# 105    1943590     æºªé£Žè°·ä¹‹æˆ˜ Playtest         Mar 24, 2022
# 145    1302840  Kooring VR Coding Adventure  2020-08-01 00:00:00
# 180    1966960        Burial Stone Playtest         Apr 13, 2022
# 214    1688630    Emperial Knights Playtest         Nov 14, 2021
# ...        ...                          ...                  ...
# 85023  2606520             Elysium Playtest          Jan 4, 2024
# 85060  2644780             Dastaan Playtest          Jan 2, 2024
# 85093  2736740                     Writeway          Jan 5, 2024
# 85108  2747170    Backpack Battles Playtest          Jan 3, 2024
# 85115  2765800   Scorching Engines Playtest          Jan 6, 2024
#
#       Estimated owners Price DLC count  \
# 31           0 - 20000  0.99         0
# 105              0 - 0     0         0
# 145          0 - 20000  8.49         0
# ...

# %%
# after exploring the Categories column i noticed some key words that are repeating which are not playable games.
# Hence i will mark it

# for any beta game the null value sups with 'Beta game not playable'
# for any Alpha game the null value sups with 'Alpha  game not playable'
# for any Test game the null value sups with 'this game game not playable'
# for any playtest game the null value sups with 'Playtest game not playable'
# for any SDK game the null value sups with 'Software Development Kit of the game not playable'
# for any Demo game the null value sups with 'Demo game not playable'
# for any server game the null value sups with 'Server of a game not playable'
# for any editor game the null value sups with 'Beta game not playable'
for index, row in Games.iterrows():
    if(pd.isnull(row['Categories'])):
        if 'Playtest' in row['Name']:
            Games.at[index, 'Categories'] = 'Playtest game not playable'
        elif "Alpha" in row['Name']:
            Games.at[index, 'Categories'] = 'Alpha game not playable'
        elif "beta" in row['Name']:
            Games.at[index, 'Categories'] = 'Beta game not playable'
        elif "BETA" in row['Name']:
            Games.at[index, 'Categories'] = 'Beta game not playable'
        elif "Test" in row['Name']:
            Games.at[index, 'Categories'] = 'test game not playable'
        elif "playtest" in row['Name']:
            Games.at[index, 'Categories'] = 'Playtest game not playable'
        elif "SDK" in row['Name']:
            Games.at[index, 'Categories'] = 'Software Development Kit of the game not playable'
        elif "Demo" in row['Name']:
            Games.at[index, 'Categories'] = 'Demo game not playable'
        elif "Server" in row['Name']:
            Games.at[index, 'Categories'] = 'Server of a game not playable'
        elif "Editor" in row['Name']:
            Games.at[index, 'Categories'] = 'Editor of a game not playable'
        elif "Beta" in row['Name']:
            Games.at[index, 'Categories'] = 'Beta game not playable'
        else:
            continue

# %%
Games.loc[Games['Categories'].isna()]
# Out:
#          AppID                                             Name  \
# 31     1727670                               Home Office Tasker
# 145    1302840                      Kooring VR Coding Adventure
# 216    2026860                  Maria Blanchard Virtual Gallery
# 359     417540                          Gamefuel Driver Control
# 450     620050                                          Start10
# ...        ...                                              ...
# 84614  2718200                       Substance 3D Designer 2024
# 84655  2530790            CyberLink PowerDirector 2024 Ultimate
# 84694  2603950  Timeline å­˜æ¡£å®ˆæŠ¤è€… -Manage your game save
# 84979  2730630                                    Shape Shifter
# 85093  2736740                                         Writeway
#
#               Release date Estimated owners   Price DLC count  \
# 31             Sep 8, 2021        0 - 20000    0.99         0
# 145    2020-08-01 00:00:00        0 - 20000    8.49         0
# ...

# %% [markdown]
# We can see that the most of the remaning rows are not games indicated by the genre column so let's sort out that column first

# %%
Games.loc[Games['Genres'].isna()]
# Out:
#          AppID                                   Name  Release date  \
# 105    1943590               æºªé£Žè°·ä¹‹æˆ˜ Playtest  Mar 24, 2022
# 180    1966960                  Burial Stone Playtest  Apr 13, 2022
# 214    1688630              Emperial Knights Playtest  Nov 14, 2021
# 220    1478660                 Slotracers VR Playtest  Dec 17, 2020
# 291    1613340  Pirates of the Asteroid Belt Playtest  Apr 23, 2021
# ...        ...                                    ...           ...
# 85020  2760980                 Z Ops: Campus Playtest   Jan 5, 2024
# 85023  2606520                       Elysium Playtest   Jan 4, 2024
# 85060  2644780                       Dastaan Playtest   Jan 2, 2024
# 85108  2747170              Backpack Battles Playtest   Jan 3, 2024
# 85115  2765800             Scorching Engines Playtest   Jan 6, 2024
#
#       Estimated owners Price DLC count Supported languages Windows    Mac  \
# 105              0 - 0     0         0                  []    True  False
# ...

# %%
# Let's fill Genres column where the game is not plable

for index, row in Games.iterrows():
    if pd.isna(row['Genres']):
        if 'not playable' in str(row['Categories']):
            Games.at[index, 'Genres'] = 'Playtest game not playable'
        else:
            continue

# %%
Games.loc[Games['Genres'].isna()]
# Out:
#          AppID                         Name         Release date  \
# 451     211208                  VectorMan 2          May 2, 2012
# 1004    211200                 Beyond Oasis          May 2, 2012
# 1346     71250           Sonic Adventure DX          Mar 4, 2011
# 3002    529640      SteamVR Driver for FOVE         Jan 11, 2019
# 4542    855060                  Huawei VR 2  2018-05-01 00:00:00
# ...        ...                          ...                  ...
# 83852  2562440           MindXcope Playtest          Dec 6, 2023
# 84310  2728330                    HZ_SERVER          Mar 6, 2024
# 84455  2372160             Strayed Playtest         Dec 22, 2023
# 84458  2722700       Space Control Playtest         Dec 21, 2023
# 84507  2716140  Milo and the Christmas Gift         Dec 22, 2023
#
#        Estimated owners Price DLC count  \
# 451               0 - 0  0.99         0
# 1004              0 - 0  0.99         0
# 1346   500000 - 1000000  7.99         0
# ...

# %%
# after exploring the genres column i noticed some key words that are repeating which are not playable games.
# Hence i will mark it

# for any beta game the null value sups with 'Beta game not playable'
# for any Alpha game the null value sups with 'Alpha  game not playable'
# for any Test game the null value sups with 'this game game not playable'
# for any playtest game the null value sups with 'Playtest game not playable'
# for any SDK game the null value sups with 'Software Development Kit of the game not playable'
# for any Demo game the null value sups with 'Demo game not playable'
# for any server game the null value sups with 'Server of a game not playable'
# for any editor game the null value sups with 'Beta game not playable'
for index, row in Games.iterrows():
    if(pd.isnull(row['Genres'])):
        if 'Playtest' in row['Name']:
            Games.at[index, 'Genres'] = 'Playtest game not playable'
        elif "Alpha" in row['Name']:
            Games.at[index, 'Genres'] = 'Alpha game not playable'
        elif "beta" in row['Name']:
            Games.at[index, 'Genres'] = 'Beta game not playable'
        elif "BETA" in row['Name']:
            Games.at[index, 'Genres'] = 'Beta game not playable'
        elif "Test" in row['Name']:
            Games.at[index, 'Genres'] = 'test game not playable'
        elif "playtest" in row['Name']:
            Games.at[index, 'Genres'] = 'Playtest game not playable'
        elif "SDK" in row['Name']:
            Games.at[index, 'Genres'] = 'Software Development Kit of the game not playable'
        elif "Demo" in row['Name']:
            Games.at[index, 'Genres'] = 'Demo game not playable'
        elif "Server" in row['Name']:
            Games.at[index, 'Genres'] = 'Server of a game not playable'
        elif "Editor" in row['Name']:
            Games.at[index, 'Genres'] = 'Editor of a game not playable'
        elif "Beta" in row['Name']:
            Games.at[index, 'Genres'] = 'Beta game not playable'
        else:
            continue

# %%
Games.loc[Games['Genres'].isna()]
# Out:
#          AppID                                       Name  \
# 451     211208                                VectorMan 2
# 1004    211200                               Beyond Oasis
# 1346     71250                         Sonic Adventure DX
# 3002    529640                    SteamVR Driver for FOVE
# 4542    855060                                Huawei VR 2
# ...        ...                                        ...
# 79530  2187080                             Dream Sketcher
# 79809  2254160  Total War: PHARAOH - Early Access Weekend
# 83446  2553960                   Conquistadorio: Prologue
# 84310  2728330                                  HZ_SERVER
# 84507  2716140                Milo and the Christmas Gift
#
#               Release date  Estimated owners Price DLC count  \
# 451            May 2, 2012             0 - 0  0.99         0
# 1004           May 2, 2012             0 - 0  0.99         0
# 1346           Mar 4, 2011  500000 - 1000000  7.99         0
# ...

# %%
# unique Genres only for the rows where 'Categories' is NaN
Games.loc[Games['Categories'].isna(), 'Genres'].unique()
# Out:
# array(['Utilities', 'Adventure,Casual,Indie,Strategy,Education',
#        'Design & Illustration,Education', 'Education',
#        'Education,Software Training',
#        'Casual,Animation & Modeling,Utilities,Game Development',
#        'Indie,Utilities', 'Photo Editing,Utilities',
#        'Animation & Modeling',
#        'Animation & Modeling,Video Production,Early Access',
#        'Design & Illustration,Utilities,Game Development',
#        'Utilities,Game Development', 'Software Training',
#        'Design & Illustration,Early Access',
#        'Animation & Modeling,Design & Illustration,Photo Editing,Utilities,Game Development,Early Access',
#        'Design & Illustration,Photo Editing',
#        'Design & Illustration,Photo Editing,Utilities',
#        'Audio Production,Education,Software Training,Utilities,Video Production',
#        'Utilities,Video Production', 'Action',
#        'Animation & Modeling,Game Development,Early Access',
# ...

# %% [markdown]
# As we can see most of the remaining NaN values in Genres are not games hence we will drop it

# %%
Games.shape
# Out:
# (85094, 12)

# %%
Games.drop(index=Games[Games['Genres'].isna()].index, inplace=True)

# %%
Games.shape
# Out:
# (84977, 12)

# %%
Games.isnull().sum()
# Out:
# AppID                     0
# Name                      0
# Release date              0
# Estimated owners          0
# Price                     0
# DLC count                 0
# Supported languages       0
# Windows                   0
# Mac                       0
# Linux                     0
# Categories             1125
# Genres                    0
# dtype: int64

# %%
Games.loc[Games['Categories'].isna()]
# Out:
#          AppID                                             Name  \
# 31     1727670                               Home Office Tasker
# 145    1302840                      Kooring VR Coding Adventure
# 216    2026860                  Maria Blanchard Virtual Gallery
# 359     417540                          Gamefuel Driver Control
# 450     620050                                          Start10
# ...        ...                                              ...
# 84614  2718200                       Substance 3D Designer 2024
# 84655  2530790            CyberLink PowerDirector 2024 Ultimate
# 84694  2603950  Timeline å­˜æ¡£å®ˆæŠ¤è€… -Manage your game save
# 84979  2730630                                    Shape Shifter
# 85093  2736740                                         Writeway
#
#               Release date Estimated owners   Price DLC count  \
# 31             Sep 8, 2021        0 - 20000    0.99         0
# 145    2020-08-01 00:00:00        0 - 20000    8.49         0
# ...

# %%
Games.drop(index=Games[Games['Categories'].isna()].index, inplace=True)

# %%
Games.isnull().sum()
# Out:
# AppID                  0
# Name                   0
# Release date           0
# Estimated owners       0
# Price                  0
# DLC count              0
# Supported languages    0
# Windows                0
# Mac                    0
# Linux                  0
# Categories             0
# Genres                 0
# dtype: int64

# %%
Games.shape
# Out:
# (83852, 12)

# %% [markdown]
# #### Deleting games which are not playable

# %%
Not_Playable = Games.loc[Games["Categories"].str.contains("game not playable", case = True) 
          | Games["Genres"].str.contains("game not playable", case = True)]
Not_Playable_index= Not_Playable.index
Not_Playable
# Out:
#          AppID                                   Name  Release date  \
# 105    1943590               æºªé£Žè°·ä¹‹æˆ˜ Playtest  Mar 24, 2022
# 180    1966960                  Burial Stone Playtest  Apr 13, 2022
# 214    1688630              Emperial Knights Playtest  Nov 14, 2021
# 220    1478660                 Slotracers VR Playtest  Dec 17, 2020
# 291    1613340  Pirates of the Asteroid Belt Playtest  Apr 23, 2021
# ...        ...                                    ...           ...
# 85020  2760980                 Z Ops: Campus Playtest   Jan 5, 2024
# 85023  2606520                       Elysium Playtest   Jan 4, 2024
# 85060  2644780                       Dastaan Playtest   Jan 2, 2024
# 85108  2747170              Backpack Battles Playtest   Jan 3, 2024
# 85115  2765800             Scorching Engines Playtest   Jan 6, 2024
#
#       Estimated owners Price DLC count Supported languages Windows    Mac  \
# 105              0 - 0     0         0                  []    True  False
# ...

# %%
Games.shape
# Out:
# (83852, 12)

# %%
Games.drop(index=Not_Playable_index, inplace=True)

# %%
Games.shape
# Out:
# (80382, 12)

# %% [markdown]
# #### Exporting the Cleaned Data

# %%
# Games.to_excel(r'C:\Users\Kritin\Desktop\Imarticus\Capstone Project 1\Steam Game Dataset\Cleaned Games.xlsx', index=False)
